# %% [markdown]
# # CLIP Interrogator 2.2 by [@pharmapsychotic](https://twitter.com/pharmapsychotic)
#
# Want to figure out what a good prompt might be to create new images like an existing one? The CLIP Interrogator is here to get you answers!
#
# <br>
#
# For Stable Diffusion 1.X choose the **ViT-L** model and for Stable Diffusion 2.0+ choose the **ViT-H** CLIP Model.
#
# This version is specialized for producing nice prompts for use with Stable Diffusion and achieves higher alignment between generated text prompt and source image. You can try out the old [version 1](https://colab.research.google.com/github/pharmapsychotic/clip-interrogator/blob/v1/clip_interrogator.ipynb) to see how different CLIP models ranks terms.
#
# You can also run this on HuggingFace and Replicate<br>
# [![Generic badge](https://img.shields.io/badge/🤗-Open%20in%20Spaces-blue.svg)](https://huggingface.co/spaces/pharma/CLIP-Interrogator) [![Replicate](https://replicate.com/pharmapsychotic/clip-interrogator/badge)](https://replicate.com/pharmapsychotic/clip-interrogator)
#
# <br>
#
# If this notebook is helpful to you please consider buying me a coffee via [ko-fi](https://ko-fi.com/pharmapsychotic) or following me on [twitter](https://twitter.com/pharmapsychotic) for more cool Ai stuff. 🙂
#
# And if you're looking for more Ai art tools check out my [Ai generative art tools list](https://pharmapsychotic.com/tools.html).

# %%
#@title Check GPU
# !nvidia-smi -L
# Out:
# 'nvidia-smi' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
#@title Setup
import os, subprocess

def setup():
    install_cmds = [
        ['pip', 'install', 'gradio'],
        ['pip', 'install', 'open_clip_torch'],
        ['pip', 'install', '-e', 'git+https://github.com/pharmapsychotic/BLIP.git@lib#egg=blip'],
        ['git', 'clone', 'https://github.com/pharmapsychotic/clip-interrogator.git']
    ]
    for cmd in install_cmds:
        print(subprocess.run(cmd, stdout=subprocess.PIPE).stdout.decode('utf-8'))

setup()


clip_model_name = 'ViT-L-14/openai' #@param ["ViT-L-14/openai", "ViT-H-14/laion2b_s32b_b79k"]


print("Download preprocessed cache files...")
CACHE_URLS = [
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-L-14_openai_artists.pkl',
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-L-14_openai_flavors.pkl',
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-L-14_openai_mediums.pkl',
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-L-14_openai_movements.pkl',
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-L-14_openai_trendings.pkl',
] if clip_model_name == 'ViT-L-14/openai' else [
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-H-14_laion2b_s32b_b79k_artists.pkl',
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-H-14_laion2b_s32b_b79k_flavors.pkl',
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-H-14_laion2b_s32b_b79k_mediums.pkl',
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-H-14_laion2b_s32b_b79k_movements.pkl',
    'https://huggingface.co/pharma/ci-preprocess/resolve/main/ViT-H-14_laion2b_s32b_b79k_trendings.pkl',
]
os.makedirs('cache', exist_ok=True)
for url in CACHE_URLS:
    print(subprocess.run(['wget', url, '-P', 'cache'], stdout=subprocess.PIPE).stdout.decode('utf-8'))


import sys
sys.path.append('src/blip')
sys.path.append('clip-interrogator')

import gradio as gr
from clip_interrogator import Config, Interrogator

config = Config()
config.blip_num_beams = 64
config.blip_offload = False
config.clip_model_name = clip_model_name
ci = Interrogator(config)

def inference(image, mode, best_max_flavors=32):
    ci.config.chunk_size = 2048 if ci.config.clip_model_name == "ViT-L-14/openai" else 1024
    ci.config.flavor_intermediate_count = 2048 if ci.config.clip_model_name == "ViT-L-14/openai" else 1024
    image = image.convert('RGB')
    if mode == 'best':
        return ci.interrogate(image, max_flavors=int(best_max_flavors))
    elif mode == 'classic':
        return ci.interrogate_classic(image)
    else:
        return ci.interrogate_fast(image)
# Out:
# Requirement already satisfied: gradio in c:\users\ruofan mo\anaconda3\lib\site-packages (3.15.0)
# Requirement already satisfied: httpx in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (0.23.1)
# Requirement already satisfied: orjson in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (3.8.3)
# Requirement already satisfied: matplotlib in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (3.5.1)
# Requirement already satisfied: ffmpy in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (0.3.0)
# Requirement already satisfied: pydantic in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (1.10.2)
# Requirement already satisfied: requests in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (2.27.1)
# Requirement already satisfied: pydub in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (0.0.5)
# Requirement already satisfied: altair>=4.2.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: numpy in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (1.22.4)
# Requirement already satisfied: fastapi in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (0.88.0)
# Requirement already satisfied: markupsafe in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (2.0.1)
# Requirement already satisfied: fsspec in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (2022.2.0)
# Requirement already satisfied: pillow in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (9.0.1)
# Requirement already satisfied: pandas in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (1.4.2)
# Requirement already satisfied: pycryptodome in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (3.16.0)
# Requirement already satisfied: pyyaml in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: aiohttp in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (3.8.1)
# Requirement already satisfied: jinja2 in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (2.11.3)
# Requirement already satisfied: uvicorn in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (2.1.0)
# Requirement already satisfied: websockets>=10.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from gradio) (10.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (4.4.0)
# Requirement already satisfied: entrypoints in c:\users\ruofan mo\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (0.4)
# Requirement already satisfied: toolz in c:\users\ruofan mo\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (0.11.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from pandas->gradio) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ruofan mo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ruofan mo\anaconda3\lib\site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from aiohttp->gradio) (2.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from aiohttp->gradio) (1.6.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ruofan mo\anaconda3\lib\site-packages (from aiohttp->gradio) (5.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\ruofan mo\anaconda3\lib\site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: idna>=2.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->gradio) (3.3)
# Requirement already satisfied: starlette==0.22.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from fastapi->gradio) (0.22.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from starlette==0.22.0->fastapi->gradio) (4.1.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from starlette==0.22.0->fastapi->gradio) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi->gradio) (1.2.0)
# Requirement already satisfied: certifi in c:\users\ruofan mo\anaconda3\lib\site-packages (from httpx->gradio) (2022.12.7)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from httpx->gradio) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\ruofan mo\anaconda3\lib\site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ruofan mo\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from markdown-it-py[linkify,plugins]->gradio) (0.1.2)
# Requirement already satisfied: mdit-py-plugins in c:\users\ruofan mo\anaconda3\lib\site-packages (from markdown-it-py[linkify,plugins]->gradio) (0.3.3)
# Requirement already satisfied: linkify-it-py~=1.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from markdown-it-py[linkify,plugins]->gradio) (1.0.3)
# Requirement already satisfied: uc-micro-py in c:\users\ruofan mo\anaconda3\lib\site-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]->gradio) (1.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from matplotlib->gradio) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from matplotlib->gradio) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from matplotlib->gradio) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ruofan mo\anaconda3\lib\site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from matplotlib->gradio) (21.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from requests->gradio) (1.26.9)
# Requirement already satisfied: click>=7.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from uvicorn->gradio) (8.0.4)
# Requirement already satisfied: colorama in c:\users\ruofan mo\anaconda3\lib\site-packages (from click>=7.0->uvicorn->gradio) (0.4.4)
#
# Collecting open_clip_torch
#   Downloading open_clip_torch-2.9.1-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: huggingface-hub in c:\users\ruofan mo\anaconda3\lib\site-packages (from open_clip_torch) (0.10.0)
# Requirement already satisfied: torch>=1.9.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from open_clip_torch) (1.12.1)
# Requirement already satisfied: protobuf==3.20.* in c:\users\ruofan mo\anaconda3\lib\site-packages (from open_clip_torch) (3.20.3)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: regex in c:\users\ruofan mo\anaconda3\lib\site-packages (from open_clip_torch) (2022.3.15)
# Requirement already satisfied: tqdm in c:\users\ruofan mo\anaconda3\lib\site-packages (from open_clip_torch) (4.64.0)
# Collecting torchvision
#   Downloading torchvision-0.14.1-cp39-cp39-win_amd64.whl (1.1 MB)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
# Requirement already satisfied: typing-extensions in c:\users\ruofan mo\anaconda3\lib\site-packages (from torch>=1.9.0->open_clip_torch) (4.1.1)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\ruofan mo\anaconda3\lib\site-packages (from ftfy->open_clip_torch) (0.2.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from huggingface-hub->open_clip_torch) (6.0)
# Requirement already satisfied: requests in c:\users\ruofan mo\anaconda3\lib\site-packages (from huggingface-hub->open_clip_torch) (2.27.1)
# Requirement already satisfied: filelock in c:\users\ruofan mo\anaconda3\lib\site-packages (from huggingface-hub->open_clip_torch) (3.6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\ruofan mo\anaconda3\lib\site-packages (from huggingface-hub->open_clip_torch) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ruofan mo\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub->open_clip_torch) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ruofan mo\anaconda3\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ruofan mo\anaconda3\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ruofan mo\anaconda3\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (2.0.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\ruofan mo\anaconda3\lib\site-packages (from torchvision->open_clip_torch) (9.0.1)
# Requirement already satisfied: numpy in c:\users\ruofan mo\anaconda3\lib\site-packages (from torchvision->open_clip_torch) (1.22.4)
# Collecting torch>=1.9.0
#   Downloading torch-1.13.1-cp39-cp39-win_amd64.whl (162.5 MB)
# Requirement already satisfied: colorama in c:\users\ruofan mo\anaconda3\lib\site-packages (from tqdm->open_clip_torch) (0.4.4)
# Installing collected packages: torch, torchvision, sentencepiece, ftfy, open-clip-torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# Successfully installed ftfy-6.1.1 open-clip-torch-2.9.1 sentencepiece-0.1.97 torch-1.13.1 torchvision-0.14.1
# Obtaining blip from git+https://github.com/pharmapsychotic/BLIP.git@lib#egg=blip
#   Cloning https://github.com/pharmapsychotic/BLIP.git (to revision lib) to c:\users\ruofan mo\desktop\bcg\src\blip
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 14>()
#      11     for cmd in install_cmds:
#      12         print(subprocess.run(cmd, stdout=subprocess.PIPE).stdout.decode('utf-8'))
# ---> 14 setup()
#      17 clip_model_name = 'ViT-L-14/openai' #@param ["ViT-L-14/openai", "ViT-H-14/laion2b_s32b_b79k"]
#      20 print("Download preprocessed cache files...")
#
# Input In [4], in setup()
#       5 install_cmds = [
#       6     ['pip', 'install', 'gradio'],
#       7     ['pip', 'install', 'open_clip_torch'],
#       8     ['pip', 'install', '-e', 'git+https://github.com/pharmapsychotic/BLIP.git@lib#egg=blip'],
#       9     ['git', 'clone', 'https://github.com/pharmapsychotic/clip-interrogator.git']
#      10 ]
#      11 for cmd in install_cmds:
# ---> 12     print(subprocess.run(cmd, stdout=subprocess.PIPE).stdout.decode('utf-8'))
#
# File ~\anaconda3\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     502     kwargs['stdout'] = PIPE
#     503     kwargs['stderr'] = PIPE
# --> 505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
#     507         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~\anaconda3\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\anaconda3\lib\subprocess.py:1420, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1418 # Start the process
#    1419 try:
# -> 1420     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                              # no special security
#    1422                              None, None,
#    1423                              int(not close_fds),
#    1424                              creationflags,
#    1425                              env,
#    1426                              cwd,
#    1427                              startupinfo)
#    1428 finally:
#    1429     # Child is launched. Close the parent's copy of those pipe
#    1430     # handles that only the child should have open.  You need
#    (...)
#    1433     # pipe will not close when the child process exits and the
#    1434     # ReadFile will hang.
#    1435     self._close_pipe_fds(p2cread, p2cwrite,
#    1436                          c2pread, c2pwrite,
#    1437                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] 系统找不到指定的文件。

# %%
#@title Image to prompt! 🖼️ -> 📝
   
inputs = [
    gr.inputs.Image(type='pil'),
    gr.Radio(['best', 'fast'], label='', value='best'),
    gr.Number(value=16, label='best mode max flavors'),
]
outputs = [
    gr.outputs.Textbox(label="Output"),
]

io = gr.Interface(
    inference, 
    inputs, 
    outputs, 
    allow_flagging=False,
)
io.launch(debug=False)

# %%
#@title Batch process a folder of images 📁 -> 📝

#@markdown This will generate prompts for every image in a folder and either save results 
#@markdown to a desc.csv file in the same folder or rename the files to contain their prompts.
#@markdown The renamed files work well for [DreamBooth extension](https://github.com/d8ahazard/sd_dreambooth_extension)
#@markdown in the [Stable Diffusion Web UI](https://github.com/AUTOMATIC1111/stable-diffusion-webui).
#@markdown You can use the generated csv in the [Stable Diffusion Finetuning](https://colab.research.google.com/drive/1vrh_MUSaAMaC5tsLWDxkFILKJ790Z4Bl?usp=sharing)

import csv
import os
from IPython.display import clear_output, display
from PIL import Image
from tqdm import tqdm

folder_path = "C:\\Users\\Ruofan Mo\\Desktop\\BCG\\dalle cats and dogs\\train_test\\Train\\Cat" #@param {type:"string"}
prompt_mode = 'best' #@param ["best","fast"]
output_mode = 'rename' #@param ["desc.csv","rename"]
max_filename_len = 128 #@param {type:"integer"}
best_max_flavors = 16 #@param {type:"integer"}


def sanitize_for_filename(prompt: str, max_len: int) -> str:
    name = "".join(c for c in prompt if (c.isalnum() or c in ",._-! "))
    name = name.strip()[:(max_len-4)] # extra space for extension
    return name

ci.config.quiet = True

files = [f for f in os.listdir(folder_path) if f.endswith('.jpg') or f.endswith('.png')] if os.path.exists(folder_path) else []
prompts = []
for idx, file in enumerate(tqdm(files, desc='Generating prompts')):
    if idx > 0 and idx % 100 == 0:
        clear_output(wait=True)

    image = Image.open(os.path.join(folder_path, file)).convert('RGB')
    prompt = inference(image, prompt_mode, best_max_flavors=best_max_flavors)
    prompts.append(prompt)

    print(prompt)
    thumb = image.copy()
    thumb.thumbnail([256, 256])
    display(thumb)

    if output_mode == 'rename':
        name = sanitize_for_filename(prompt, max_filename_len)
        ext = os.path.splitext(file)[1]
        filename = name + ext
        idx = 1
        while os.path.exists(os.path.join(folder_path, filename)):
            print(f'File {filename} already exists, trying {idx+1}...')
            filename = f"{name}_{idx}{ext}"
            idx += 1
        os.rename(os.path.join(folder_path, file), os.path.join(folder_path, filename))

if len(prompts):
    if output_mode == 'desc.csv':
        csv_path = os.path.join(folder_path, 'desc.csv')
        with open(csv_path, 'w', encoding='utf-8', newline='') as f:
            w = csv.writer(f, quoting=csv.QUOTE_MINIMAL)
            w.writerow(['image', 'prompt'])
            for file, prompt in zip(files, prompts):
                w.writerow([file, prompt])

        print(f"\n\n\n\nGenerated {len(prompts)} prompts and saved to {csv_path}, enjoy!")
    else:
        print(f"\n\n\n\nGenerated {len(prompts)} prompts and renamed your files, enjoy!")
else:
    print(f"Sorry, I couldn't find any images in {folder_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 27>()
#      24     name = name.strip()[:(max_len-4)] # extra space for extension
#      25     return name
# ---> 27 ci.config.quiet = True
#      29 files = [f for f in os.listdir(folder_path) if f.endswith('.jpg') or f.endswith('.png')] if os.path.exists(folder_path) else []
#      30 prompts = []
#
# NameError: name 'ci' is not defined
